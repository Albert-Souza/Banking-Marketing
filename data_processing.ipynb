# %%
import pandas as pd

# %%
df = pd.read_csv('Data/bank-additional-full.csv', sep=';')
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
df2 = df.drop(columns=df.columns[15:20])
df2.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  duration  campaign  pdays  previous     poutcome   y
# 0   may         mon       261         1    999         0  nonexistent  no
# 1   may         mon       149         1    999         0  nonexistent  no
# 2   may         mon       226         1    999         0  nonexistent  no
# 3   may         mon       151         1    999         0  nonexistent  no
# 4   may         mon       307         1    999         0  nonexistent  no

# %%
df3 = df2.rename({
    'age': 'Idade',
    'job': 'Ocupação',
    'marital': 'Estado Civil',
    'education': 'Escolaridade',
    'default': 'Default',
    'housing': 'Empréstimo Imobiliário',
    'loan': 'Empréstimo Pessoal',
    'contact': 'Contato',
    'month': 'Mês',
    'day_of_week': 'Dia da Semana',
    'duration': 'Duração',
    'campaign': 'Campanha',
    'pdays': 'Dias Passados',
    'previous': 'Contatos Anteriores',
    'poutcome': 'Resultado Anterior',
    'y': 'Resultado'
}, axis=1)

df3.head()
# Out:
#    Idade   Ocupação Estado Civil Escolaridade  Default Empréstimo Imobiliário  \
# 0     56  housemaid      married     basic.4y       no                     no
# 1     57   services      married  high.school  unknown                     no
# 2     37   services      married  high.school       no                    yes
# 3     40     admin.      married     basic.6y       no                     no
# 4     56   services      married  high.school       no                     no
#
#   Empréstimo Pessoal    Contato  Mês Dia da Semana  Duração  Campanha  \
# 0                 no  telephone  may           mon      261         1
# 1                 no  telephone  may           mon      149         1
# 2                 no  telephone  may           mon      226         1
# 3                 no  telephone  may           mon      151         1
# 4                yes  telephone  may           mon      307         1
#
#    Dias Passados  Contatos Anteriores Resultado Anterior Resultado
# ...

# %%
df4 = df3.copy()

df4['Ocupação'] = df4['Ocupação'].replace({
    "admin.": "Administrativo",
    "unknown": "Desconhecido",
    "unemployed": "Desempregado",
    "management": "Gerência",
    "housemaid": "Empregada Doméstica",
    "entrepreneur": "Empreendedor",
    "student": "Estudante",
    "blue-collar": "Operário",
    "self-employed": "Autônomo",
    "retired": "Aposentado",
    "technician": "Técnico",
    "services": "Serviços"
})

df4['Estado Civil'] = df4['Estado Civil'].replace({
    'married': 'Casado',
    'single': 'Solteiro',
    'divorced': 'Divorciado',
    "unknown": "Desconhecido"
})

df4['Escolaridade'] = df4['Escolaridade'].replace({
    "basic.4y": "Fundamental (4º ano)",
    "basic.6y": "Fundamental (6º ano)",
    "basic.9y": "Fundamental (9º ano)",
    "high.school": "Ensino Médio",
    "illiterate": "Analfabeto",
    "professional.course": "Curso Profissionalizante",
    "university.degree": "Ensino Superior",
    "unknown": "Desconhecido"
})

df4['Default'] = df4['Default'].replace({
    'yes': 'Sim',
    'no': 'Não',
    'unknown': 'Desconhecido'
})

df4['Empréstimo Imobiliário'] = df4['Empréstimo Imobiliário'].replace({
    'yes': 'Sim',
    'no': 'Não',
    'unknown': 'Desconhecido'
})

df4['Empréstimo Pessoal'] = df4['Empréstimo Pessoal'].replace({
    'yes': 'Sim',
    'no': 'Não',
    'unknown': 'Desconhecido'
})

df4['Contato'] = df4['Contato'].replace({
    "telephone": "Telefone Fixo",
    "cellular": "Celular",
    "unknown": "Desconhecido"
})

df4['Resultado Anterior'] = df4['Resultado Anterior'].replace({
    'success': 'Sucesso',
    'failure': 'Falha',
    'nonexistent': 'Não Existente'
})

df4['Resultado'] = df4['Resultado'].replace({
    'yes': 'Sucesso',
    'no': 'Falha'
})

df4['Mês'] = df4['Mês'].replace({
    "jan": '1',
    "feb": '2',
    "mar": '3',
    "apr": '4',
    "may": '5',
    "jun": '6',
    "jul": '7',
    "aug": '8',
    "sep": '9',
    "oct": '10',
    "nov": '11',
    "dec": '12'
}).astype(int)

df4['Dia da Semana'] = df4['Dia da Semana'].replace({
    "sun": '1',
    "mon": '2',
    "tue": '3',
    "wed": '4',
    "thu": '5',
    "fri": '6',
    "sat": '7'
}).astype(int)

df4.head()
# Out:
#    Idade             Ocupação Estado Civil          Escolaridade  \
# 0     56  Empregada Doméstica       Casado  Fundamental (4º ano)
# 1     57             Serviços       Casado          Ensino Médio
# 2     37             Serviços       Casado          Ensino Médio
# 3     40       Administrativo       Casado  Fundamental (6º ano)
# 4     56             Serviços       Casado          Ensino Médio
#
#         Default Empréstimo Imobiliário Empréstimo Pessoal        Contato  Mês  \
# 0           Não                    Não                Não  Telefone Fixo    5
# 1  Desconhecido                    Não                Não  Telefone Fixo    5
# 2           Não                    Sim                Não  Telefone Fixo    5
# 3           Não                    Não                Não  Telefone Fixo    5
# 4           Não                    Não                Sim  Telefone Fixo    5
#
#    Dia da Semana  Duração  Campanha  Dias Passados  Contatos Anteriores  \
# ...

# %%
df5 = df4.copy()
df5['Dias Passados'] = df5['Dias Passados'].replace({999: -1})

df5.head()
# Out:
#    Idade             Ocupação Estado Civil          Escolaridade  \
# 0     56  Empregada Doméstica       Casado  Fundamental (4º ano)
# 1     57             Serviços       Casado          Ensino Médio
# 2     37             Serviços       Casado          Ensino Médio
# 3     40       Administrativo       Casado  Fundamental (6º ano)
# 4     56             Serviços       Casado          Ensino Médio
#
#         Default Empréstimo Imobiliário Empréstimo Pessoal        Contato  Mês  \
# 0           Não                    Não                Não  Telefone Fixo    5
# 1  Desconhecido                    Não                Não  Telefone Fixo    5
# 2           Não                    Sim                Não  Telefone Fixo    5
# 3           Não                    Não                Não  Telefone Fixo    5
# 4           Não                    Não                Sim  Telefone Fixo    5
#
#    Dia da Semana  Duração  Campanha  Dias Passados  Contatos Anteriores  \
# ...

# %%
df5.to_excel('Data/processed_data.xlsx', index=False)
